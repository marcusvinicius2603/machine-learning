# %% [markdown]
# <a href="https://colab.research.google.com/github/marcusvinicius2603/machine-learning/blob/main/tratamento_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# SERIES = Colunas

# %%
df = pd.Series(index = ['a','b','c','d'], data = [3,-5,7,4])
df
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %% [markdown]
# OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU OU

# %%
df = pd.DataFrame(index = 'a b c d '.split(), data = '3, -5, 7, 4'.split())
df
# Out:
#      0
# a   3,
# b  -5,
# c   7,
# d    4

# %% [markdown]
# DATAFRAME = Linhas e Colunas

# %%
df = pd.DataFrame(np.random.randn(5, 4), index = 'A B C D E'.split(), columns = ['Dia', 'Tempo', 'Pressão', 'Ar'])
df
# Out:
#         Dia     Tempo   Pressão        Ar
# A -1.074678 -1.465118 -0.514121  0.073843
# B  0.021961  2.200561 -0.203395  0.521665
# C  0.582834 -0.989396 -1.231688 -0.211931
# D  0.063289 -0.330273 -0.947482  0.071454
# E -0.085098  0.859473 -2.091033 -1.872619

# %%
type(df['Dia'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df > 0
# Out:
#      Dia  Tempo  Pressão     Ar
# A  False   True    False   True
# B   True   True     True   True
# C  False  False    False   True
# D   True  False     True  False
# E  False   True    False   True

# %%
x = df > 0
df[x]
# Out:
#         Dia     Tempo   Pressão        Ar
# A       NaN  0.331484       NaN  0.003815
# B  1.874099  1.737257  0.143983  1.409102
# C       NaN       NaN       NaN  0.331872
# D  0.220843       NaN  0.630167       NaN
# E       NaN  0.628039       NaN  0.441435

# %% [markdown]
# SOMANDO AS QUANTIDADES - Números Positivos

# %%
df[x].count()
# Out:
# Dia        2
# Tempo      3
# Pressão    2
# Ar         4
# dtype: int64

# %%
df[x].count().sum()
# Out:
# 11

# %% [markdown]
# SOMANDO OS VALORES - Números Positivos

# %%
df[x].sum()
# Out:
# Dia        2.094943
# Tempo      2.696779
# Pressão    0.774150
# Ar         2.186225
# dtype: float64

# %%
df[x].sum().sum()
# Out:
# 7.752096845920873

# %% [markdown]
# FILTRANDO E SOMANDO COLUNAS

# %%
df['Dia']
# Out:
# A   -0.398469
# B    1.874099
# C   -1.734031
# D    0.220843
# E   -0.038451
# Name: Dia, dtype: float64

# %%
df['Dia'].sum()
# Out:
# -0.07600885958861081

# %%
df[['Dia', 'Tempo', 'Pressão']]
# Out:
#         Dia     Tempo   Pressão
# A -0.398469  0.331484 -1.042228
# B  1.874099  1.737257  0.143983
# C -1.734031 -1.024094 -1.209532
# D  0.220843 -0.487577  0.630167
# E -0.038451  0.628039 -1.089927

# %%
df[['Dia', 'Tempo', 'Pressão']].sum()
# Out:
# Dia       -0.076009
# Tempo      1.185108
# Pressão   -2.567537
# dtype: float64

# %%
df[['Dia', 'Tempo', 'Pressão']].sum().sum()
# Out:
# -1.4584382519484462

# %% [markdown]
# FILTRANDO LINHAS

# %%
df = pd.DataFrame(
                  {'País' : ['Bélgica', 'índia', 'Brasil'],
                  'Capital' : ['Bruxelas', 'Nova Delphi', 'Brasília'],
                  'População' : [123.465, 987.654, 456.789]},                  
                  index=[1, 2, 3],
                  )
df
# Out:
#       País      Capital  População
# 1  Bélgica     Bruxelas    123.465
# 2    índia  Nova Delphi    987.654
# 3   Brasil     Brasília    456.789

# %%
df.loc[1]
# Out:
# País          Bélgica
# Capital      Bruxelas
# População     123.465
# Name: 1, dtype: object

# %%
df.loc[1, 'País']
# Out:
# 'Bélgica'

# %%
df.loc[3, 'Capital']
# Out:
# 'Brasília'

# %%
df.iloc[1:2]
# Out:
#     País      Capital  População
# 2  índia  Nova Delphi    987.654

# %%
df.iloc[1:3]
# Out:
#      País      Capital  População
# 2   índia  Nova Delphi    987.654
# 3  Brasil     Brasília    456.789

# %%
df.iloc[1:3, 2:3]
# Out:
#    População
# 2    987.654
# 3    456.789

# %% [markdown]
# 2:3 = Começo na 2 coluna (excluindo-a) e vou até a a 3 coluna
# 1:3 = Começo na 1 linha (excluindo-a) e vou até a 3 linha

# %% [markdown]
# Filtrando Brasília:

# %%
df.iloc[2:3, 1:2]
# Out:
#     Capital
# 3  Brasília

# %%
df['Continente'] = ['Europa', 'Ásia', 'América do Sul']
df
# Out:
#       País      Capital  População      Continente
# 1  Bélgica     Bruxelas    123.465          Europa
# 2    índia  Nova Delphi    987.654            Ásia
# 3   Brasil     Brasília    456.789  América do Sul

# %%
df.set_index('Continente', inplace= True)
df
# Out:
#                    País      Capital  População
# Continente
# Europa          Bélgica     Bruxelas    123.465
# Ásia              índia  Nova Delphi    987.654
# América do Sul   Brasil     Brasília    456.789

# %%
df['Nova'] = df['País'] + df['Capital']
df
# Out:
#                    País      Capital  População              Nova
# Continente
# Europa          Bélgica     Bruxelas    123.465   BélgicaBruxelas
# Ásia              índia  Nova Delphi    987.654  índiaNova Delphi
# América do Sul   Brasil     Brasília    456.789    BrasilBrasília

# %% [markdown]
# EXCLUINDO COLUNA

# %%
df.drop('Nova', axis = 1)
# Out:
#                    País      Capital  População
# Continente
# Europa          Bélgica     Bruxelas    123.465
# Ásia              índia  Nova Delphi    987.654
# América do Sul   Brasil     Brasília    456.789

# %%
df
# Out:
#                    País      Capital  População              Nova
# Continente
# Europa          Bélgica     Bruxelas    123.465   BélgicaBruxelas
# Ásia              índia  Nova Delphi    987.654  índiaNova Delphi
# América do Sul   Brasil     Brasília    456.789    BrasilBrasília

# %% [markdown]
# EXCLUINDO COLUNA - em definitivo

# %%
df.drop('Nova', axis=1, inplace=True)

# %%
df
# Out:
#                    País      Capital  População
# Continente
# Europa          Bélgica     Bruxelas    123.465
# Ásia              índia  Nova Delphi    987.654
# América do Sul   Brasil     Brasília    456.789

# %%
df['Nova'] = df['País'] + df['Capital']
df
# Out:
#                    País      Capital  População              Nova
# Continente
# Europa          Bélgica     Bruxelas    123.465   BélgicaBruxelas
# Ásia              índia  Nova Delphi    987.654  índiaNova Delphi
# América do Sul   Brasil     Brasília    456.789    BrasilBrasília

# %%
df.drop(['População', 'Nova'], axis = 1)
# Out:
#                    País      Capital
# Continente
# Europa          Bélgica     Bruxelas
# Ásia              índia  Nova Delphi
# América do Sul   Brasil     Brasília

# %% [markdown]
# REVERTENDO EXCLUSÃO

# %%
df.drop(['População', 'Nova'], axis=0, errors = 'ignore')
# Out:
#                    País      Capital  População              Nova
# Continente
# Europa          Bélgica     Bruxelas    123.465   BélgicaBruxelas
# Ásia              índia  Nova Delphi    987.654  índiaNova Delphi
# América do Sul   Brasil     Brasília    456.789    BrasilBrasília

# %% [markdown]
# EXCLUINDO LINHA

# %% [markdown]
# ... por alguma motivo esse tipo de exclusão não tá funcionando

# %%
df.drop(1)

# %% [markdown]
# DADOS AUSENTES

# %%
df = pd.DataFrame(
    {'A' : [1, 2, np.nan],
    'B': [5, np.nan, np.nan],
    'C': [9, 10, 11]}  
    )
df
# Out:
#      A    B   C
# 0  1.0  5.0   9
# 1  2.0  NaN  10
# 2  NaN  NaN  11

# %% [markdown]
# ... não entendi!!!

# %%
df.dropna(0)
# Out:
#      A    B  C
# 0  1.0  5.0  9

# %%
df.fillna(value=999)
# Out:
#        A      B   C
# 0    1.0    5.0   9
# 1    2.0  999.0  10
# 2  999.0  999.0  11

# %%
df.fillna(method = 'ffill')
# Out:
#      A    B   C
# 0  1.0  5.0   9
# 1  2.0  5.0  10
# 2  2.0  5.0  11

# %%
df['A'].fillna(value = df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# GROUP BY

# %%
df= pd.DataFrame({
    'Empresa' : ['CESAR', 'BB', 'BB', 'CAIXA', 'CESAR', 'CAIXA'],
    'Nome' : ['Everton', 'Carla', 'Carla', 'Raúl', 'Hugo', 'Raúl'],
    'Venda' : [200, 320, 140, 125, 900, 1200]
    })
df
# Out:
#   Empresa     Nome  Venda
# 0   CESAR  Everton    200
# 1      BB    Carla    320
# 2      BB    Carla    140
# 3   CAIXA     Raúl    125
# 4   CESAR     Hugo    900
# 5   CAIXA     Raúl   1200

# %%
grupo = df.groupby('Empresa')

# %%
grupo.sum()
# Out:
#          Venda
# Empresa
# BB         460
# CAIXA     1325
# CESAR     1100

# %%
grupo.mean()
# Out:
#          Venda
# Empresa
# BB       230.0
# CAIXA    662.5
# CESAR    550.0

# %%
grupo.describe()
# Out:
#         Venda
#         count   mean         std    min     25%    50%     75%     max
# Empresa
# BB        2.0  230.0  127.279221  140.0  185.00  230.0  275.00   320.0
# CAIXA     2.0  662.5  760.139790  125.0  393.75  662.5  931.25  1200.0
# CESAR     2.0  550.0  494.974747  200.0  375.00  550.0  725.00   900.0

# %%
grupo = df.groupby('Nome')

# %%
grupo.sum()
# Out:
#          Venda
# Nome
# Carla      460
# Everton    200
# Hugo       900
# Raúl      1325

# %% [markdown]
# CONCATENAR

# %%
df1 = pd.DataFrame({'A' : ['A0', 'A1', 'A2', 'A3'],
                  'B' : ['B0', 'B1', 'B2', 'B3'],
                  'C' : ['C0', 'C1', 'C2', 'C3'],
                  'D' : ['D0', 'D1', 'D2', 'D3']},
                  index=[0, 1, 2, 3],
                  )
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame({'A':['A4','A5', 'A6', 'A7'],
                   'B':['B4','B5', 'B6', 'B7'],
                   'C':['C4','C5', 'C6', 'C7'],
                   'D':['D4','D5', 'D6', 'D7']},
                  index=[4,5,6,7])
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3 = pd.DataFrame({'A':['A8','A9', 'A10', 'A11'],
                   'B':['B8','B9', 'B10', 'B11'],
                   'C':['C8','C9', 'C10', 'C11'],
                   'D':['D8','D9', 'D10', 'D11']},
                  index=[8,9,10,11])
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3], axis = 1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
# MESCLAR

# %% [markdown]
# Tem que ter 1 Linha em comum

# %%
esquerda = pd.DataFrame({'key':['K0','K1', 'K2', 'K3'],
                   'A':['A0','A1', 'A2', 'A3'],
                   'B':['B0','B1', 'B2', 'B3']})
direita = pd.DataFrame({'key':['K0','K1', 'K2', 'K3'],
                   'C':['C0','C1', 'C2', 'C3'],
                   'D':['D0','D1', 'D2', 'D3']})

# %%
esquerda
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
direita
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(esquerda, direita, how='inner', on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %% [markdown]
# IMPORTANDO DADOS

# %% [markdown]
# 1) Importando Dados de Sites que Contenham Tabelas

# %%
site = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %%
site[0]
# Out:
#                                             Minnesota                                        Minnesota.1
# 0                                               State                                              State
# 1                                  State of Minnesota                                 State of Minnesota
# 2   .mw-parser-output .ib-settlement-cols{text-ali...  .mw-parser-output .ib-settlement-cols{text-ali...
# 3   Nickname(s): Land of 10,000 Lakes;North Star S...  Nickname(s): Land of 10,000 Lakes;North Star S...
# 4   Motto(s): L'Étoile du Nord (French: The Star o...  Motto(s): L'Étoile du Nord (French: The Star o...
# 5                           Anthem: "Hail! Minnesota"                          Anthem: "Hail! Minnesota"
# 6   Map of the United States with Minnesota highli...  Map of the United States with Minnesota highli...
# 7                                             Country                                      United States
# ...

# %%
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
site2 = pd.read_html('https://www.ibge.gov.br/indicadores#variacao-do-pib')

# %%
site2[0]
# Out:
#                                Indicadores econômicos  ...                                             No ano
# 0                                            IPCA (%)  ...                                      No ano  10,06
# 1   Periodicidade:  Mensal Abrangência:  Brasil, R...  ...  Periodicidade:  Mensal Abrangência:  Brasil, R...
# 2                                            INPC (%)  ...                                      No ano  10,16
# 3   Periodicidade:  Mensal Abrangência:  Brasil, R...  ...  Periodicidade:  Mensal Abrangência:  Brasil, R...
# 4                                         IPCA-15 (%)  ...                                       No ano  0,58
# 5   Periodicidade:  Mensal Abrangência:  Brasil, R...  ...  Periodicidade:  Mensal Abrangência:  Brasil, R...
# 6                                             IPP (%)  ...                                      No ano  28,36
# ...

# %% [markdown]
# 2) Importando Dados de Arquivos

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ae12615-54cc-4ea9-becb-e7eb88b836a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ae12615-54cc-4ea9-becb-e7eb88b836a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Salaries.csv to Salaries (1).csv

# %%
salaries = pd.read_csv('Salaries.csv')

# %%
salaries.head(200000)
# Out:
#           Id       EmployeeName  ...         Agency  Status
# 0          1     NATHANIEL FORD  ...  San Francisco     NaN
# 1          2       GARY JIMENEZ  ...  San Francisco     NaN
# 2          3     ALBERT PARDINI  ...  San Francisco     NaN
# 3          4  CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4          5    PATRICK GARDNER  ...  San Francisco     NaN
# ...      ...                ...  ...            ...     ...
# 73442  73443   Cherish  Murdock  ...  San Francisco     NaN
# 73443  73444    Michael C Rubin  ...  San Francisco     NaN
# 73444  73445   Kenneth B Linney  ...  San Francisco     NaN
# 73445  73446   Albert H Holt Jr  ...  San Francisco     NaN
# 73446  73447    Elyse R Duckett  ...            NaN     NaN
#
# [73447 rows x 13 columns]

# %% [markdown]
# Se colocar vazio, salaries.head(), vai puxar as 5 primeiras linhas

# %%
salaries.head()
# Out:
#    Id       EmployeeName  ...         Agency  Status
# 0   1     NATHANIEL FORD  ...  San Francisco     NaN
# 1   2       GARY JIMENEZ  ...  San Francisco     NaN
# 2   3     ALBERT PARDINI  ...  San Francisco     NaN
# 3   4  CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4   5    PATRICK GARDNER  ...  San Francisco     NaN
#
# [5 rows x 13 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-64e383d7-5aff-443e-a37c-f26f2889a9bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64e383d7-5aff-443e-a37c-f26f2889a9bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
titanic = pd.read_csv('train.csv')

# %%
titanic.head(20000)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e0d32d5b-1af5-4381-a7d3-042360e0ec5e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0d32d5b-1af5-4381-a7d3-042360e0ec5e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving exemplo.csv to exemplo.csv

# %%
exemplo = pd.read_csv('exemplo.csv')

# %%
exemplo.head()
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15
